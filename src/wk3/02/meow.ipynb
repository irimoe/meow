# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sbn

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 6, 11]

plt.plot(x, y)

# %%
x1 = ["cookie", "estrogen", "bread", "milk"]
y1 = [1, 2.20, 1.8, 2]

plt.plot(x1, y1)

# %%
data = pd.read_csv("../../wk2/01/datasets/iris.csv")
plt.plot(data.Id, data["SepalLengthCm"], "p")
